# %% [markdown]
# <a href="https://colab.research.google.com/github/hugofilipe-oliveiragomes/lab-dw-data-cleaning-and-formatting/blob/main/Quest_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/GSAF5.xls")
#df = pd.read_excel("https://docs.google.com/spreadsheets/d/1VakWBodBO6YWqJefpHaP6YO_IYR1llfy/edit?usp=drive_link.xls")

display(df.head())
# Out:
#           Date    Year        Type    Country             State  \
# 0  14 Feb-2024  2024.0  Unprovoked      INDIA       Maharashtra
# 1  04-Feb-2024  2024.0    Provoked   TRINIDAD               NaN
# 2  29 Jan-2024  2024.0  Unprovoked  AUSTRALIA  New  South Wales
# 3  15 Jan-2024  2024.0  Unprovoked    BAHAMAS   Paradise Island
# 4  09-Jan-2024  2024.0  Unprovoked  AUSTRALIA   South Australia
#
#                            Location      Activity                 Name Sex  \
# 0  Vaitarna River, Palghar District       Fishing  Vicky Suresh Govari   M
# 1                               NaN  Spearfishing                 male   M
# 2      Elizabeth Bay, Sydney Harbor      Swimming       Lauren O'Neill   F
# 3            Paradise Island Resort      Swimming                 male   M
# 4           Walkers Beach, Elliston       Surfing         Murray Adams   M
#
#    Age  ...             Species                            Source  pdf  \
# ...

# %%
df.describe(include = "all")
# Out:
#           Date         Year        Type Country    State  \
# count   6940.0  6938.000000        6922    6890     6458
# unique  5999.0          NaN          12     225      902
# top     1957.0          NaN  Unprovoked     USA  Florida
# freq       9.0          NaN        5103    2536     1178
# mean       NaN  1934.351686         NaN     NaN      NaN
# std        NaN   272.991147         NaN     NaN      NaN
# min        NaN     0.000000         NaN     NaN      NaN
# 25%        NaN  1947.000000         NaN     NaN      NaN
# 50%        NaN  1985.000000         NaN     NaN      NaN
# 75%        NaN  2009.000000         NaN     NaN      NaN
# max        NaN  2024.000000         NaN     NaN      NaN
#
#                                 Location Activity  Name   Sex     Age  ...  \
# count                               6375     6355  6721  6361  3947.0  ...
# unique                              4510     1587  5681     8   243.0  ...
# ...

# %%
df[["Injury", "Species "]]
# Out:
#                               Injury             Species
# 0     Calf of lower left leg injured       Bull shark, 7'
# 1                    Shoulder bitten  Blacktip reef shark
# 2                   Right leg bitten           Bull shark
# 3                 Right leg injured                   NaN
# 4                         Leg bitten          White shark
# ...                              ...                  ...
# 6960                             NaN                  NaN
# 6961                             NaN                  NaN
# 6962                             NaN                  NaN
# 6963                             NaN                  NaN
# 6964                             NaN                  NaN
#
# [6965 rows x 2 columns]

# %%
df.nunique()
# Out:
# Date              5999
# Year               259
# Type                12
# Country            225
# State              902
# Location          4510
# Activity          1587
# Name              5681
# Sex                  8
# Age                243
# Injury            4078
# Unnamed: 11         12
# Time               410
# Species           1674
# Source            5298
# pdf               6789
# href formula      6785
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
list(df.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'State',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Unnamed: 11',
#  'Time',
#  'Species ',
#  'Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number',
#  'Case Number.1',
#  'original order',
#  'Unnamed: 21',
#  'Unnamed: 22']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6965, step=1)

# %%
df.describe()[["Year"]]
# Out:
#               Year
# count  6938.000000
# mean   1934.351686
# std     272.991147
# min       0.000000
# 25%    1947.000000
# 50%    1985.000000
# 75%    2009.000000
# max    2024.000000

# %%
df.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Unnamed: 11        object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
df.isna().any()
# Out:
# Date              True
# Year              True
# Type              True
# Country           True
# State             True
# Location          True
# Activity          True
# Name              True
# Sex               True
# Age               True
# Injury            True
# Unnamed: 11       True
# Time              True
# Species           True
# Source            True
# pdf               True
# href formula      True
# href              True
# Case Number       True
# Case Number.1     True
# original order    True
# Unnamed: 21       True
# Unnamed: 22       True
# dtype: bool

# %%
df.isna().sum()
# Out:
# Date                25
# Year                27
# Type                43
# Country             75
# State              507
# Location           590
# Activity           610
# Name               244
# Sex                604
# Age               3018
# Injury              60
# Unnamed: 11        586
# Time              3550
# Species           3157
# Source              44
# pdf                166
# href formula       146
# href               169
# Case Number        167
# Case Number.1      168
# original order     166
# Unnamed: 21       6964
# Unnamed: 22       6963
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6940 non-null   object
#  1   Year            6938 non-null   float64
#  2   Type            6922 non-null   object
#  3   Country         6890 non-null   object
#  4   State           6458 non-null   object
#  5   Location        6375 non-null   object
#  6   Activity        6355 non-null   object
#  7   Name            6721 non-null   object
#  8   Sex             6361 non-null   object
#  9   Age             3947 non-null   object
#  10  Injury          6905 non-null   object
#  11  Unnamed: 11     6379 non-null   object
#  12  Time            3415 non-null   object
#  13  Species         3808 non-null   object
#  14  Source          6921 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6819 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year  original order
# count  6938.000000     6799.000000
# mean   1934.351686     3401.152081
# std     272.991147     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2024.000000     6802.000000

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#              Date    Year        Type             Country              State  \
# 0     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           AUSTRALIA   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             BAHAMAS    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           AUSTRALIA    South Australia
# ...           ...     ...         ...                 ...                ...
# 6936  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6938    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6939    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
# 6940          NaN     NaN         NaN                 NaN                NaN
#
# ...

# %%
df.columns = [ col.replace(" ","_").lower() for col in df.columns]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6941 entries, 0 to 6940
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6940 non-null   object
#  1   year            6938 non-null   float64
#  2   type            6922 non-null   object
#  3   country         6890 non-null   object
#  4   state           6458 non-null   object
#  5   location        6375 non-null   object
#  6   activity        6355 non-null   object
#  7   name            6721 non-null   object
#  8   sex             6361 non-null   object
#  9   age             3947 non-null   object
#  10  injury          6905 non-null   object
#  11  unnamed:_11     6379 non-null   object
#  12  time            3415 non-null   object
#  13  species_        3808 non-null   object
#  14  source          6921 non-null   object
#  15  pdf             6799 non-null   object
#  16  href_formula    6795 non-null   object
# ...

# %%
df["sex"].unique()
# Out:
# array(['M', 'F', nan, ' M', 'M ', 'lli', 'M x 2', 'N', '.'], dtype=object)

# %%
misspellings_F = ['F']
for f in misspellings_F:
    df['sex'] = df['sex'].replace(f, 'F')

misspellings_M = [' M', 'M ', 'M x 2', 'M']
for m in misspellings_M:
    df['sex'] = df['sex'].replace(m, 'M')

misspellings_NA = ['lli', 'N', '.']
for na in misspellings_NA:
    df['sex'] = df['sex'].replace(na, 'NA')

df["sex"].unique()
# Out:
# array(['M', 'F', nan, 'NA'], dtype=object)

# %%
df["type"].unique()
# Out:
# array(['Unprovoked', ' Provoked', 'Provoked', 'Questionable',
#        'Watercraft', 'Sea Disaster', nan, '?', 'Unconfirmed',
#        'Unverified', 'Invalid', 'Under investigation', 'Boat'],
#       dtype=object)

# %%
misspellings_Pro = [' Provoked']
for p in misspellings_Pro:
    df["type"] = df["type"].replace(p, 'Provoked')

df["type"].unique()
# Out:
# array(['Unprovoked', 'Provoked', 'Questionable', 'Watercraft',
#        'Sea Disaster', nan, '?', 'Unconfirmed', 'Unverified', 'Invalid',
#        'Under investigation', 'Boat'], dtype=object)

# %%
df["injury"].unique()
# Out:
# array(['Calf of lower left leg injured', 'Shoulder bitten',
#        'Right leg bitten', ..., 'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
fatals = ['FATAL, leg stripped of flesh  ', 'FATAL, knocked overboard by tail of shark & carried off by shark ', 'FATAL. "Shark bit him in half, carrying away the lower extremities" ']
non_fatals = ['Calf of lower left leg injured', 'Shoulder bitten','Right leg bitten',]

def get_fatal(injury):
    if injury in fatals:
        return "Fatal"
    elif injury in non_fatals:
        return "Non-Fatal"
df['fatal'] = df['injury'].apply(get_fatal)
df['fatal'].unique()
# Out:
# array(['Non-Fatal', None, 'Fatal'], dtype=object)

# %%
count_nan = [sum(df.loc[x, ['year','type', 'country','activity','age','injury','fatal']].isna())
             for x in range(len(df.index))]
df['count_nan'] = pd.Series(count_nan)

drop_lines = [line for line in range(len(df.index)) if df.loc[line,'count_nan'] == 5]
df
# Out:
#              date    year        type             country              state  \
# 0     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           AUSTRALIA   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             BAHAMAS    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           AUSTRALIA    South Australia
# ...           ...     ...         ...                 ...                ...
# 6936  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6938    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6939    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
# 6940          NaN     NaN         NaN                 NaN                NaN
#
# ...

# %%
df['count_nan'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 7])

# %%
df["type"].unique()
# Out:
# array(['Unprovoked', 'Provoked', 'Questionable', 'Watercraft',
#        'Sea Disaster', nan, '?', 'Unconfirmed', 'Unverified', 'Invalid',
#        'Under investigation', 'Boat'], dtype=object)

# %%
df["species_"].unique()
# Out:
# array(["Bull shark, 7'", 'Blacktip reef shark', 'Bull shark', ...,
#        "12' tiger shark", 'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)

# %%
df["country"].nunique()
# Out:
# 225

# %%
df["location"].nunique()
# Out:
# 4510

# %%
df["state"].nunique()
# Out:
# 902

# %%
df["activity"].nunique()
# Out:
# 1587

# %%
activity_counts = df['activity'].value_counts() #Hugo
activities_with_more_than_5_entries = activity_counts[activity_counts > 5].index.tolist()

# %%
filtered_df = df[df['activity'].isin(activities_with_more_than_5_entries)] #Hugo

# %%
activities_after_2000 = df[df['year'] > 2000] #Hugo

# %%
activity_counts_filtered = filtered_df['activity'].value_counts() ##Hugo

# %%
unique_activities_filtered = filtered_df["activity"].unique() #Hugo

# %%
num_unique_activities_filtered = filtered_df["activity"].nunique() #Hugo

# %%
sorted_activity_counts_filtered = filtered_df["activity"].value_counts().sort_values() #Hugo

# %%
print(activities_with_more_than_5_entries) #Hugo
# Out:
# ['Surfing', 'Swimming', 'Fishing', 'Spearfishing', 'Wading', 'Bathing', 'Diving', 'Snorkeling', 'Standing', 'Scuba diving', 'Body boarding', 'Body surfing', 'Swimming ', 'Boogie boarding', 'Kayaking', 'Free diving', 'Treading water', 'Fell overboard', 'Pearl diving', 'Windsurfing', 'Walking', 'Boogie Boarding', 'Canoeing', 'Floating', 'Fishing ', 'Shark fishing', 'Surf fishing', 'Playing', 'Surf-skiing', 'Rowing', 'Surf skiing', 'Scuba Diving', 'Surf skiing ', 'Paddle boarding', 'Freediving', 'Fishing for sharks', 'Sponge diving', 'Diving for trochus', 'Stand-Up Paddleboarding', 'Kayak Fishing', 'Sitting on surfboard', 'Sailing', 'Fell into the water', 'Spearfishing ', 'Sea disaster', 'Shipwreck', 'Floating on his back', 'Surfing (sitting on his board)', 'Skindiving', 'Free diving for abalone', 'Kayak fishing', 'Kite Surfing', 'Fishing for mackerel', 'Murder', 'Body Boarding', 'Sea Disaster', 'Spearfishing on Scuba', 'Kite surfing']

# %%
#Hugo
activity_mapping = {
    'Body Boarding': 'Water Sports',
    'Sea Disaster': 'Water Sports',
    'Murder': '-',
    'Kite Surfing': 'Water Sports',
    'Fishing for mackerel': 'Fishing',
    'Spearfishing on Scuba': 'Water Sports',
    'Kite surfing': 'Water Sports',
    'Surfing (sitting on his board)': 'Water Sports',
    'Kayak fishing': 'Water Sports',
    'Skindiving': 'Water Sports',
    'Floating on his back': 'Water Sports',
    'Free diving for abalone': 'Water Sports',
    'Shipwreck': 'Water Sports',
    'Spearfishing': 'Water Sports',
    'Sea disaster': 'Water Sports',
    'Kayak Fishing': 'Water Sports',
    'Stand-Up Paddleboarding': 'Water Sports',
    'Fell into the water': 'Water Sports',
    'Sitting on surfboard': 'Water Sports',
    'Diving for trochus': 'Water Sports',
    'Sailing': 'Water Sports',
    'Sponge diving': 'Water Sports',
    'Freediving': 'Water Sports',
    'Paddle boarding': 'Water Sports',
    'Fishing for sharks': 'Fishing',
    'Rowing': 'Water Sports',
    'Surf skiing': 'Water Sports',
    'Scuba Diving': 'Water Sports',
    'Playing': 'Recreation',
    'Surf-skiing': 'Water Sports',
    'Surf fishing': 'Fishing',
    'Shark fishing': 'Fishing',
    'Floating': 'Water Sports',
    'Fishing': 'Fishing',
    'Canoeing': 'Water Sports',
    'Boogie Boarding': 'Water Sports',
    'Walking': 'Recreation',
    'Windsurfing': 'Water Sports',
    'Pearl diving': 'Water Sports',
    'Fell overboard': 'Water Sports',
    'Treading water': 'Water Sports',
    'Free diving': 'Water Sports',
    'Kayaking': 'Water Sports',
    'Boogie boarding': 'Water Sports',
    'Swimming': 'Water Sports',
    'Body surfing': 'Water Sports',
    'Body boarding': 'Water Sports',
    'Scuba diving': 'Water Sports',
    'Standing': 'Recreation',
    'Snorkeling': 'Water Sports',
    'Diving': 'Water Sports',
    'Bathing': 'Recreation',
    'Wading': 'Water Sports'
}

# %%
activities_after_2000 = df[df['year'] > 2000].copy() #Hugo

# %%
activities_after_2000.loc[:, "activity_mapped"] = activities_after_2000["activity"].map(activity_mapping) #Hugo

# %%
display(activities_after_2000) #Hugo
# Out:
#                        date    year        type      country  \
# 0               14 Feb-2024  2024.0  Unprovoked        INDIA
# 1               04-Feb-2024  2024.0    Provoked     TRINIDAD
# 2               29 Jan-2024  2024.0  Unprovoked    AUSTRALIA
# 3               15 Jan-2024  2024.0  Unprovoked      BAHAMAS
# 4               09-Jan-2024  2024.0  Unprovoked    AUSTRALIA
# ...                     ...     ...         ...          ...
# 2588  Reported  24-Jan-2001  2001.0  Watercraft    AUSTRALIA
# 2589            24-Jan-2001  2001.0  Unprovoked         CUBA
# 2590            21-Jan-2001  2001.0  Watercraft    AUSTRALIA
# 2591            09-Jan-2001  2001.0  Unprovoked          USA
# 2592            06-Jan-2001  2001.0  Watercraft  NEW ZEALAND
#
#                  state                          location      activity  \
# 0          Maharashtra  Vaitarna River, Palghar District       Fishing
# 1                  NaN                               NaN  Spearfishing
# ...

# %%
df.drop(drop_lines, axis = 0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6940 entries, 0 to 6940
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6939 non-null   object
#  1   year            6937 non-null   float64
#  2   type            6921 non-null   object
#  3   country         6890 non-null   object
#  4   state           6458 non-null   object
#  5   location        6375 non-null   object
#  6   activity        6355 non-null   object
#  7   name            6720 non-null   object
#  8   sex             6360 non-null   object
#  9   age             3947 non-null   object
#  10  injury          6905 non-null   object
#  11  unnamed:_11     6378 non-null   object
#  12  time            3415 non-null   object
#  13  species_        3808 non-null   object
#  14  source          6920 non-null   object
#  15  pdf             6798 non-null   object
#  16  href_formula    6794 non-null   object
# ...

# %%
df = df.drop(drop_lines, axis = 0)
df
# Out:
#              date    year        type             country              state  \
# 0     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           AUSTRALIA   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             BAHAMAS    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           AUSTRALIA    South Australia
# ...           ...     ...         ...                 ...                ...
# 6936  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6938    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6939    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
# 6940          NaN     NaN         NaN                 NaN                NaN
#
# ...

# %%
from typing_extensions import AsyncGenerator
#Possible starting questions/hypotheses:

1. What is the period of the database? 2000 until 2024 (Angie)
cleaning:
Hugo: Activity
Karl: Age
Mariana: species
2. What year were shark attacks most common?
3. What is the percentage of attacks that end in death?
4. In which geographical area do they occur most frequently?
5. In what situations?
# Out:
#   File "<ipython-input-47-929cd4e0f328>", line 4
#     1. What is the period of the database? 2000 until 2024 (Angie)
#        ^
# SyntaxError: invalid syntax

# %%
from datetime import timedelta
df['new_date']=pd.to_datetime(df['date'], errors='coerce')
df['new_data_month']=df.new_date.dt.month

# %%
df['country']=df['country'].apply(str)
df['country']=df['country'].apply(lambda x: x.lower())

# %%
def clean_country(country):
  for x in country:
    country=country.replace('?','').replace('?','')
  return country

df['country']=df['country'].apply(clean_country)

# %%
continent={"admiralty islands":"oceania","africa":"africa","algeria":"africa","american samoa":"north america","andaman / nicobar islandas":"asia","andaman islands":"asia","angola":"africa",
"antigua":"antigua","argentina":"south america","aruba":"north america","asia":"asia","atlantic ocean":"atlantic ocean","australia":"oceania","azores":"europe","bahamas":"north america","bahrein":"asia",
"bangladesh":"asia","barbados":"north america","bay of bengal":"asia","belize":"north america","bermuda":"north america","between portugal & india":"asian and europa","brazil":"south america",
"british isles":"europe","british new guinea":"oceania","british overseas territory":"europe","british overseas territory":"europe","british virgin islands":"north america","british west indies":"central caribbean","burma":"asia",
"canada":"north america","cape verde":"africa","caribbean sea":"south america","cayman islands":"north america","central pacific":"central pacific","ceylon":"asia","ceylon (sri lanka)]":"asia","chile":"south america","china":"asia",
"coast of africa":"africa","colombia":"south america","columbia":"north america","comoros":"africa","cook islands":"pacific ocean","coral sea":"oceania",
"costa rica":"north america","crete":"europe","croatia":"europe","cuba":"north america","curacao":"south america","cyprus":"europe","diego garcia":"asia","djibouti":"africa","dominican republic":"north america","ecuador":"south america","egypt":"africa","egypt ":"africa","egypt / israel":"africa","el salvador":"north america","england":"europe","equatorial guinea / cameroon":"africa","falkland islands":"south america","federated states of micronesia":"oceania","fiji":"oceania","france":"europe","french polynesia":"oceania","gabon":"africa","georgia":"asia","ghana":"africa","grand cayman":"north america","greece":"europe","greenland":"north america","grenada":"north america","guam":"oceania","guatemala":"north america","guinea":"africa","gulf of aden":"africa","guyana":"south america","haiti":"north america","honduras":"north america","hong kong":"asia","iceland":"europe","india":"asia","indian ocean":"asia","indonesia":"asia","iran":"asia","iran / iraq":"asia","iraq":"asia","ireland":"europe","israel":"asia","italy":"europe","italy / croatia":"europe","jamaica":"north america","japan":"asia","java":"asia","johnston island":"north america","jordan":"asia","kenya":"africa","kiribati":"oceania","korea":"asia","kuwait":"asia","lebanon":"asia",
"liberia":"africa","libya":"africa","madagascar":"africa","malaysia":"asia","maldive islands":"asia","maldives":"asia","malta":"europe",
"marshall islands":"oceania","martinique":"north america","mauritius":"africa","mayotte":"asia",
"mediterranean sea":"mediterranean sea","mexico":"north america","mexico ":"south america","micronesia":"oceania","mid atlantic ocean":"atlantic ocean","mid-pacifc ocean":"pacific ocean","monaco":"europe","montenegro":"europe","mozambique":"africa","namibia":"africa","nan":"nan",
"netherlands antilles":"center america","nevis":"center america","new britain":"oceania",
"new caledonia":"oceania","new guinea":"oceania","new zealand":"oceania","nicaragua":"north america",
"nicaragua ":"north america","nigeria":"africa","north atlantic ocean":"atlantic ocean","north atlantic ocean ":"atlantic ocean","north pacific ocean":"pacific ocean","north sea":"north sea","northern arabian sea":"idian ocean","northern mariana islands":"oceania","norway":"europe",
"ocean":"ocean","okinawa":"asia","pacific ocean":"pacific ocean","pacific ocean ":"pacific ocean","palau":"oceania","palestinian territories":"asia","panama":"north america","papua new guinea":"oceania","paraguay":"south america","persian gulf":"asia","peru":"south america","philippines":"asia","philippines":"asia","portugal":"europe","puerto rico":"north america","red sea":"asia","red sea / indian ocean":"asia","reunion":"nan","reunion island":"nan","roatan":"nan","russia":"europe","samoa":"oceania","san domingo":"nan","saudi arabia":"asia",
"scotland":"nan","senegal":"africa","seychelles":"africa","sierra leone":"africa","singapore":"asia","slovenia":"europe","solomon islands":"oceania","solomon islands / vanuatu":"oceania","somalia":"africa","south africa":"africa","south atlantic ocean":"atlantic ocean","south china sea":"asia","south korea":"asia","south pacific ocean":"pacific ocean","southwest pacific ocean":"pacific ocean","spain":"europe",
"sri lanka":"asia","st helena":"africa","st kitts / nevis":"north america","st martin":"center america","st. maartin":"center america","st. martin":"center america","sudan":"africa","syria":"asia","taiwan":"asia","tanzania":"africa","tasman sea":"africa","thailand":"asia","the balkans":"europe","tobago":"south america","tonga":"oceania","tonga":"oceania","trinidad":"south america","trinidad & tobago":"south america","tunisia":"africa","turkey":"asia","turks & caicos":"north america","turks and caicos":"north america","tuvalu":"oceania","united arab emirates":"asia","united arab emirates (uae)":"asia","united kingdom":"europe","uruguay":"south america","usa":"north america","vanuatu":"oceania","venezuela":"south america","vietnam":"asia","west indies":"asia","western samoa":"oceania","yemen":"asia"}

# %%
df['continent'] = df['country'].map(continent)

# %%
import pandas as pd
import numpy as np
import re


def simple_clean_age(value):
    if pd.isnull(value):
        return np.nan

    value = str(value)

    if 'teen' in value.lower():
        return 15
    elif 'adult' in value.lower():
        return 30
    elif 'elderly' in value.lower():
        return 70
    elif 'young' in value.lower():
        return 20

    match = re.search(r'\d+', value)
    return float(match.group()) if match else np.nan

df['age'] = df['age'].apply(simple_clean_age)

df['age'] = pd.to_numeric(df['age'])

print(df)
# Out:
#              date    year        type             country              state  \
# 0     14 Feb-2024  2024.0  Unprovoked               india        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            trinidad                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           australia   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             bahamas    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           australia    South Australia
# ...           ...     ...         ...                 ...                ...
# 6936  Before 1903     0.0  Unprovoked           australia  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 usa     North Carolina
# 6938    1883-1889     0.0  Unprovoked              panama                NaN
# 6939    1845-1853     0.0  Unprovoked  ceylon (sri lanka)   Eastern Province
# 6940          NaN     NaN         NaN                 nan                NaN
#
# ...

# %%
df.age.fillna(df.age.mean(), inplace=True)

# %%
df['age'].isna().sum()
# Out:
# 0

# %%
df['age'].unique()
# Out:
# array([32.        , 27.95654384, 29.        , 10.        , 64.        ,
#        62.        , 39.        , 22.        , 15.        , 16.        ,
#        46.        , 21.        , 66.        , 52.        , 20.        ,
#        44.        , 26.        , 47.        , 55.        , 30.        ,
#        59.        ,  8.        , 50.        , 45.        , 34.        ,
#        38.        , 37.        ,  9.        , 19.        , 35.        ,
#        65.        , 77.        , 60.        , 49.        , 42.        ,
#         2.        , 24.        , 73.        , 25.        , 18.        ,
#        13.        , 11.        , 58.        , 67.        , 17.        ,
#        14.        ,  6.        , 41.        , 53.        , 68.        ,
#        43.        , 40.        , 51.        , 31.        , 33.        ,
#        28.        , 56.        , 12.        , 36.        , 27.        ,
#        57.        ,  7.        , 71.        , 48.        , 54.        ,
# ...

# %%
df['age'] = df['age'].round(0)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Read data from Excel file
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Quest_2/GSAF5.xls")

# Display first few rows of the dataframe
display(df.head())

# Get summary statistics of the dataframe
df.describe(include="all")

# Select specific columns from the dataframe
df[["Injury", "Species "]]

# Count unique values in each column
df.nunique()

# List all columns in the dataframe
list(df.columns)

# Display the index of the dataframe
df.index

# Display datatypes of columns
df.dtypes

# Check for missing values in each column
df.isna().any()

# Count missing values in each column
df.isna().sum()

# Display information about the dataframe
df.info()

# Perform another round of summary statistics
df.describe()

# Check for duplicated rows
df.duplicated().any()

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Replace spaces with underscores and convert column names to lowercase
df.columns = [col.replace(" ", "_").lower() for col in df.columns]
df.info()

# Drop the columns we are not going to use
df = df.drop((['unnamed:_11','pdf', 'href_formula','href', 'case_number', 'case_number.1', 'original_order', 'unnamed:_21', 'unnamed:_22']), axis = 1)
df

# Filtering data from 2000 onwards
df = df[df['year'] >= 2000]

# Check unique values in the "sex" column
df["sex"].unique()

# Clean misspellings and inconsistencies in the "sex" column
# Define misspellings and their replacements
misspellings_mapping = {
    'F': 'F',
    ' M': 'M',
    'M ': 'M',
    'M x 2': 'M',
    'M': 'M',
    'lli': 'NA',
    'N': 'NA',
    '.': 'NA'
}

# Loop through the misspellings_mapping and perform replacements using .loc
for misspelling, replacement in misspellings_mapping.items():
    df.loc[df['sex'] == misspelling, 'sex'] = replacement

print(df)

# Check unique values in the "sex" column after cleaning
df["sex"].unique()

# Check unique values in the "type" column
df["type"].unique()

# Clean misspellings and inconsistencies in the "type" column
misspellings_Pro = [' Provoked']
for p in misspellings_Pro:
    df["type"] = df["type"].replace(p, 'Provoked')

# Check unique values in the "type" column after cleaning
df["type"].unique()

# Check unique values in the "injury" column
df["injury"].unique()

# Define lists of fatal and non-fatal injuries
fatals = ['FATAL, leg stripped of flesh  ', 'FATAL, knocked overboard by tail of shark & carried off by shark ', 'FATAL. "Shark bit him in half, carrying away the lower extremities" ']
non_fatals = ['Calf of lower left leg injured', 'Shoulder bitten', 'Right leg bitten']

# Function to categorize injuries as fatal or non-fatal
def get_fatal(injury):
    if injury in fatals:
        return "Fatal"
    elif injury in non_fatals:
        return "Non-Fatal"

# Apply the function to create a new column "fatal"
df['fatal'] = df['injury'].apply(get_fatal)
df['fatal'].unique()

# Count the number of missing values in certain columns for each row
count_nan = [sum(df.loc[x, ['year', 'type', 'country', 'activity', 'age', 'injury', 'fatal', 'species_']].isna())
             for x in range(len(df.index))]
df['count_nan'] = pd.Series(count_nan)

# Identify lines with 5 missing values and drop them
drop_lines = [line for line in range(len(df.index)) if df.loc[line, 'count_nan'] == 5]
df = df.drop(drop_lines, axis=0)

# Check unique values in the "type" column after dropping lines
df["type"].unique()

# Check unique values in the "species_" column
df["species_"].unique()

# Count the number of unique countries, locations, states, and activities
df["country"].nunique()
df["location"].nunique()
df["state"].nunique()
df["activity"].nunique()

# Perform some data analysis related to activities
activity_counts = df['activity'].value_counts()  # Count occurrences of each activity
activities_with_more_than_5_entries = activity_counts[activity_counts > 5].index.tolist()  # Get activities with more than 5 entries
filtered_df = df[df['activity'].isin(activities_with_more_than_5_entries)]  # Filter dataframe by selected activities
activities_after_2000 = df[df['year'] > 2000]  # Filter dataframe for records after 2000

# Display filtered dataframe and relevant information
display(activities_after_2000)

# Define a mapping for activities and apply it to create a new column
activity_mapping = {
    # Define mappings...
}

# Apply mapping to create a new column "activity_mapped"
activities_after_2000.loc[:, "activity_mapped"] = activities_after_2000["activity"].map(activity_mapping)

# Display the dataframe with the new column
display(activities_after_2000)

# Clean and categorize data related to age
def simple_clean_age(value):
    # Define cleaning logic...
    return cleaned_value

df['age'] = df['age'].apply(simple_clean_age)
df['age'] = pd.to_numeric(df['age'])
df.age.fillna(df.Age.mean(), inplace=True)
df['age'].unique()
df['age'] = df['age'].round(0)

# Data cleaning related to date and country
df['new_date'] = pd.to_datetime(df['date'], errors='coerce')
df['new_data_month'] = df.new_date.dt.month

df['country'] = df['country'].apply(str)
df['country'] = df['country'].apply(lambda x: x.lower())

def clean_country(country):
    # Define country cleaning logic...
    return cleaned_country

df['country'] = df['country'].apply(clean_country)

continent = {
    # Define continent mapping...
}

df['continent'] = df['country'].map(continent)

# %%
pattern_species = r'white|carcharias|bull|leucas|tiger|cuvier|whitetip|shortfin|oceanic|mako'

df['Species_clean'] = df['species_'].map(lambda x: re.findall(pattern_species, str(x))).map(lambda x: x[0] if len(x) > 0 else np.nan)

# %%
shark_attack_counts = df['Species_clean'].value_counts()

print(shark_attack_counts.head(5))
# Out:
# white      234
# bull        58
# tiger       57
# mako        12
# oceanic      9
# Name: Species_clean, dtype: int64

# %%
shark_species_dict = {
    'white': 'Great White Shark',
    'carcharias': 'Great White Shark',
    'tiger': 'Tiger Shark',
    'cuvier': 'Tiger Shark',
    'bull': 'Bull Shark',
    'leucas': 'Bull Shark',
    'whitetip': 'Oceanic Whitetip Shark',
    'longimanus': 'Oceanic Whitetip Shark',
    'mako': 'Shortfin Mako Shark',
    'isurus': 'Shortfin Mako Shark'
}

# %%
df['Corrected_Species'] = df['Species_clean'].map(shark_species_dict)

# %%
df['country'].value_counts().sort_values(ascending=False).head(10)
# Out:
# usa                 2536
# australia           1479
# south africa         598
# new zealand          145
# bahamas              136
# papua new guinea     136
# brazil               122
# mexico               105
# italy                 72
# fiji                  70
# Name: country, dtype: int64

# %%
df
# Out:
#              date    year        type             country              state  \
# 0     14 Feb-2024  2024.0  Unprovoked               india        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            trinidad                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           australia   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             bahamas    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           australia    South Australia
# ...           ...     ...         ...                 ...                ...
# 6936  Before 1903     0.0  Unprovoked           australia  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 usa     North Carolina
# 6938    1883-1889     0.0  Unprovoked              panama                NaN
# 6939    1845-1853     0.0  Unprovoked  ceylon (sri lanka)   Eastern Province
# 6940          NaN     NaN         NaN                 nan                NaN
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize': (100,100)})

# %%
sns.barplot(x='Corrected_Species', ='fatal', data=df)
# Out:
# <Axes: xlabel='Corrected_Species', ylabel='fatal'>

# %%
sns.barplot(x='Corrected_Species', data=df)
# Out:
# <Axes: xlabel='Corrected_Species'>

# %%
sns.barplot(x='Corrected_Species', y='fatal', data=df)
# Out:
# <Axes: xlabel='Corrected_Species', ylabel='fatal'>

# %%
sns.histplot(x='fatal', y='Corrected_Species', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-5d96486d44b6> in <cell line: 1>()
# ----> 1 sns.histplot(x='fatal', y='Corrected_Species', data=df)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1432     else:
#    1433
# -> 1434         p.plot_bivariate_histogram(
#    1435             common_bins=common_bins,
#    1436             common_norm=common_norm,
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6940 entries, 0 to 6940
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               6939 non-null   object
#  1   year               6937 non-null   float64
#  2   type               6921 non-null   object
#  3   country            6940 non-null   object
#  4   state              6458 non-null   object
#  5   location           6375 non-null   object
#  6   activity           6355 non-null   object
#  7   name               6720 non-null   object
#  8   sex                6360 non-null   object
#  9   age                6940 non-null   float64
#  10  injury             6905 non-null   object
#  11  unnamed:_11        6378 non-null   object
#  12  time               3415 non-null   object
#  13  species_           3808 non-null   object
#  14  source             6920 non-null   object
#  15  pdf                6798 non-null   object
# ...

# %%
df.Corrected_Species.isna().sum()
# Out:
# 6576

# %%
import plotly.express as px

# Assuming 'df_simulated' is your DataFrame and it has 'Year' and 'Count' columns
# Aggregate data by 'Year' if not already done
yearly_counts = df_simulated.groupby('Year').size().reset_index(name='Count')

# Create an interactive line chart
fig = px.line(yearly_counts, x='Year', y='Count', title='Interactive Trend Analysis of Shark Attacks Over the Years', markers=True)

# Display the figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec6650cbaa6c> in <cell line: 5>()
#       3 # Assuming 'df_simulated' is your DataFrame and it has 'Year' and 'Count' columns
#       4 # Aggregate data by 'Year' if not already done
# ----> 5 yearly_counts = df_simulated.groupby('Year').size().reset_index(name='Count')
#       6
#       7 # Create an interactive line chart
#
# NameError: name 'df_simulated' is not defined
